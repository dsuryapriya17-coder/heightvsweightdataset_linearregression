# %% [markdown]
# <a href="https://colab.research.google.com/github/dsuryapriya17-coder/heightvsweightdataset_linearregression/blob/main/heightvsweightdataset_linearregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/data.csv')

# %%
data.head()
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4    1.57   57.20

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  15 non-null     float64
#  1   Weight  15 non-null     float64
# dtypes: float64(2)
# memory usage: 372.0 bytes

# %%
data.describe()
# Out:
#           Height     Weight
# count  15.000000  15.000000
# mean    1.650667  62.078000
# std     0.114235   7.037515
# min     1.470000  52.210000
# 25%     1.560000  56.520000
# 50%     1.650000  61.290000
# 75%     1.740000  67.190000
# max     1.830000  74.460000

# %%
plt.figure(figsize=(10,10))
sns.pairplot(data,x_vars=['YearsExperience'],y_vars=['Salary'],size=7,kind='scatter')
plt.xlabel=('height')
plt.ylabel=('weight')
plt.show()

# %%
x=data['Height']
x.head()
# Out:
# 0    1.47
# 1    1.50
# 2    1.52
# 3    1.55
# 4    1.57
# Name: Height, dtype: float64

# %%
y=data['Weight']
y.head()
# Out:
# 0    52.21
# 1    53.12
# 2    54.48
# 3    55.84
# 4    57.20
# Name: Weight, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_preadict=lr.predict(x_train)

# %%
mse_train=mean_squared_error(y_train,y_predict)

# %%
from sklearn.metrics import r2_score
r2_train=r2_score(y_train,y_train_predict)

# %%
print('Mse',mse_train)
print('accuracy',r2_train)
# Out:
# Mse 0.52488181236489
# accuracy 0.9878077378236708

# %%
c = [i for i in range (1,len(y_test)+1)]
y_predict = lr.predict(x_test.values.reshape(-1, 1)) # Calculate predictions for the test set and reshape x_test
plt.plot(c,y_test,color='r',linestyle='-')
plt.plot(c,y_predict,color='b',linestyle='-')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Prediction')
plt.show()

# %%
c=[i for i in range(1,len(y_test)+1)]
plt.plot(c,y_test-y_predict,color='green',linestyle='-')
plt.xlabel('weight')
plt.ylabel('Error')
plt.title('Error value')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mse_test=mean_squared_error(y_test,y_predict)

# %%
r2_test=r2_score(y_test,y_predict)

# %%
print('Mse',mse_test)
print('accuracy',r2_test)
# Out:
# Mse 0.4650271771810253
# accuracy 0.9901998577485844

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test,y_predict,color='r',linestyle='-')
plt.show()

# %%
print('intercept of the model',lr.intercept_)
print('coeff of the model',lr.coef_)
# Out:
# intercept of the model -37.99076005188071
# coeff of the model [60.63899697]
